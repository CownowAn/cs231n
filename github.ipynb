# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)

# %cd {github에 올릴 디렉토리 경로}
FOLDERNAME = 'cs231n/assignments/'
# %cd drive/My\ Drive/$FOLDERNAME
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs231n/assignments

# %%
# !git config --global user.email "user@email.com"
# !git config --global user.name "username"
# !git config --global user.email "cownow4425@gmail.com"
# !git config --global user.name "cownow4425"

# %%
# !git add .
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git commit -m "Creat cs231n repo"
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git remote add origin https://{personal_access_token}@github.com/cownow4425/cs231n-.git

# %%
# !git push -u origin master
